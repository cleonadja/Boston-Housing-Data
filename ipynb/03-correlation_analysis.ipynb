# %%
boston_df = read.csv('/home/jovyan/Project3/data/bostonhousing.csv', header=FALSE, sep='')

# %%
colnames(boston_df) = c('crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black','lstat', 'medv')

# %%
install.packages('rpart')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(caret)
library(rpart)
# Out:
# Loading required package: lattice

# %%
calculate_r_2 <- function(actual, prediction) {
    return (1 - (sum((actual-prediction)^2)/sum((actual-mean(actual))^2)))
}

calculate_r_2_for_feature <- function(data, feature) {
    n <- nrow(data)
    
    train_index <- sample(seq_len(n), size = 0.8*n)

    train <- data[train_index,]
    test <- data[-train_index,]
    
    this_formula = paste(feature,"~.")
    fit <- rpart(data=train, formula=as.formula(this_formula))

    y_test <- as.vector(test[[feature]])
    test[feature] <- NULL
    predictions <- predict(fit, test)
    return (calculate_r_2(y_test, predictions))
}

# %%
print(paste("Crime rate: ", calculate_r_2_for_feature(boston_df,'crim')))
print(paste("Res land for over 25k sqf: ", calculate_r_2_for_feature(boston_df,'zn')))
print(paste("Non retail acres: ", calculate_r_2_for_feature(boston_df,'indus')))
print(paste("River: ", calculate_r_2_for_feature(boston_df,'chas')))
print(paste("Nitrogen oxide: ", calculate_r_2_for_feature(boston_df,'nox')))
print(paste("Rooms: ", calculate_r_2_for_feature(boston_df,'rm')))
print(paste("Age: ", calculate_r_2_for_feature(boston_df,'age')))
print(paste("Boston employment centers: ", calculate_r_2_for_feature(boston_df,'dis')))
print(paste("Highways: ", calculate_r_2_for_feature(boston_df,'rad')))
print(paste("Property tax: ", calculate_r_2_for_feature(boston_df,'tax')))
print(paste("Pupil-teacher ratio: ", calculate_r_2_for_feature(boston_df,'ptratio')))
print(paste("Proportion of blacks: ", calculate_r_2_for_feature(boston_df,'black')))
print(paste("Lower pop status: ", calculate_r_2_for_feature(boston_df,'lstat')))
print(paste("Median value: ", calculate_r_2_for_feature(boston_df,'medv')))
# Out:
# [1] "Crime rate:  0.464672019389856"
# [1] "Res land for over 25k sqf:  0.896307960300608"
# [1] "Non retail acres:  0.883293811889229"
# [1] "River:  -0.117878233607548"
# [1] "Nitrogen oxide:  0.810825125272343"
# [1] "Rooms:  0.566540843256341"
# [1] "Age:  0.739148838898257"
# [1] "Boston employment centers:  0.875832079208296"
# [1] "Highways:  0.788514569581203"
# [1] "Property tax:  0.944267872755787"
# [1] "Pupil-teacher ratio:  0.799105548074847"
# [1] "Proportion of blacks:  0.37880047395535"
# [1] "Lower pop status:  0.749538102717312"
# [1] "Median value:  0.754344368023624"

# %% [markdown]
# Based on the above it seems as if property tax and closeness to Boston employment centers can be predicted by the rest of the features. below we are using the full dataset to make gain more confidence.

# %%
mean_r_2_for_feature <- function (data, feature) {
    scores = c()
    for (i in 1:100) {
        scores = c(scores, calculate_r_2_for_feature(data, feature))
    }
    
    return (mean(scores))
}

# %%
print(paste("Crime rate: ", mean_r_2_for_feature(boston_df,'crim')))
print(paste("Res land for over 25k sqf: ", mean_r_2_for_feature(boston_df,'zn')))
print(paste("Non retail acres: ", mean_r_2_for_feature(boston_df,'indus')))
print(paste("River: ", mean_r_2_for_feature(boston_df,'chas')))
print(paste("Nitrogen oxide: ", mean_r_2_for_feature(boston_df,'nox')))
print(paste("Rooms: ", mean_r_2_for_feature(boston_df,'rm')))
print(paste("Age: ", mean_r_2_for_feature(boston_df,'age')))
print(paste("Boston employment centers: ", mean_r_2_for_feature(boston_df,'dis')))
print(paste("Highways: ", mean_r_2_for_feature(boston_df,'rad')))
print(paste("Property tax: ", mean_r_2_for_feature(boston_df,'tax')))
print(paste("Pupil-teacher ratio: ", mean_r_2_for_feature(boston_df,'ptratio')))
print(paste("Proportion of blacks: ", mean_r_2_for_feature(boston_df,'black')))
print(paste("Lower pop status: ", mean_r_2_for_feature(boston_df,'lstat')))
print(paste("Median value: ", mean_r_2_for_feature(boston_df,'medv')))
# Out:
# [1] "Crime rate:  0.381788264659646"
# [1] "Res land for over 25k sqf:  0.800103035770905"
# [1] "Non retail acres:  0.863224313905454"
# [1] "River:  -0.0469747008473942"
# [1] "Nitrogen oxide:  0.831927318069999"
# [1] "Rooms:  0.494396599690348"
# [1] "Age:  0.695254489657545"
# [1] "Boston employment centers:  0.793052093158051"
# [1] "Highways:  0.888317214070832"
# [1] "Property tax:  0.902733068035783"
# [1] "Pupil-teacher ratio:  0.795873773356649"
# [1] "Proportion of blacks:  0.209193550519316"
# [1] "Lower pop status:  0.683793755586688"
# [1] "Median value:  0.720567131700228"

# %% [markdown]
# For the whole dataset we are seeing similar results, however, it seems the access to highways and property tax are the most likely to e accurately predicetd by the other features.

# %%
pairs(boston_df)
# Out:
# plot without title

# %% [markdown]
# In the above pairplot in regards to correlation to the median value of the home number of rooms (rm) is showing a strong positive correlation and the percent of lower status of the population (lstat) is showing a stong negative correlation. Below we are looking at the values to get a better idea.

# %%
cor(boston_df)
# Out:
#         crim        zn          indus       chas         nox
# crim     1.00000000 -0.20046922  0.40658341 -0.055891582  0.42097171
# zn      -0.20046922  1.00000000 -0.53382819 -0.042696719 -0.51660371
# indus    0.40658341 -0.53382819  1.00000000  0.062938027  0.76365145
# chas    -0.05589158 -0.04269672  0.06293803  1.000000000  0.09120281
# nox      0.42097171 -0.51660371  0.76365145  0.091202807  1.00000000
# rm      -0.21924670  0.31199059 -0.39167585  0.091251225 -0.30218819
# age      0.35273425 -0.56953734  0.64477851  0.086517774  0.73147010
# dis     -0.37967009  0.66440822 -0.70802699 -0.099175780 -0.76923011
# rad      0.62550515 -0.31194783  0.59512927 -0.007368241  0.61144056
# tax      0.58276431 -0.31456332  0.72076018 -0.035586518  0.66802320
# ptratio  0.28994558 -0.39167855  0.38324756 -0.121515174  0.18893268
# black   -0.38506394  0.17552032 -0.35697654  0.048788485 -0.38005064
# lstat    0.45562148 -0.41299457  0.60379972 -0.053929298  0.59087892
# ...

# %% [markdown]
# The strongest correlation can be described as a positive correlation between the property taxes and the accessibility to highways. Strong negative correlation can be observed between the nitrogen oxide concentration, age of the home, and the proportion of non-retail business acres per town to the weighted mean of distances to five Boston employment centres. Also, a stong positive correlation between the age of the home and the distance to five boston employment centers as well as for average number of rooms and the median value of the home can be observed.

# %%
library(reshape2)
cormat = cor(boston_df)

# %%
cormat[lower.tri(cormat)] <- NA

# %%
melted_cormat <- melt(cormat, na.rm = T)

# %%
library(ggplot2)
ggplot(data = melted_cormat, aes(Var2, Var1, fill = value))+
 geom_tile(color = "white")+
 scale_fill_gradient2(low = "blue", high = "red", mid = "white", 
   midpoint = 0, limit = c(-1,1), space = "Lab", 
   name="Pearson\nCorrelation") +
  theme_minimal()+ 
 theme(axis.text.x = element_text(angle = 45, vjust = 1, 
    size = 12, hjust = 1))+
 coord_fixed()
# Out:
# plot without title
